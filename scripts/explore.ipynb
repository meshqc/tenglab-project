# %%
import pandas as pd
import numpy as np

# %%
#load expression matrix
expr = pd.read_csv('/Users/animeshsingh/Documents/TengLab-project/data/raw/GSE142987_series_matrix.txt.gz', sep='\t', index_col=0, skiprows=29)

print(f"Shape: {expr.shape}")  # Should be ~20,000 genes × 65 samples
print(f"Sample names: {expr.columns[:5]}")
print(f"Gene names: {expr.index[:5]}")
    
# Basic statistics
print("---------------Description below------------")
print(expr.describe())
# Out:
# Shape: (48, 65)
# Sample names: Index(['GSM4247473', 'GSM4247474', 'GSM4247475', 'GSM4247476', 'GSM4247477'], dtype='object')
# Gene names: Index(['!Sample_status', '!Sample_submission_date', '!Sample_last_update_date',
#        '!Sample_type', '!Sample_channel_count'],
#       dtype='object', name='!Sample_geo_accession')
# ---------------Description below------------
#                  GSM4247473           GSM4247474           GSM4247475  \
# count                    43                   43                   43
# unique                   42                   42                   42
# top     Tsinghua University  Tsinghua University  Tsinghua University
# freq                      2                    2                    2
#
#                  GSM4247476           GSM4247477           GSM4247478  \
# count                    43                   43                   43
# unique                   42                   42                   42
# ...
